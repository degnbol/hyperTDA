# %%
import numpy as np
import pandas as pd
import tadasets
import matplotlib.pyplot as plt

# %%
for i in range(500):
    torus = tadasets.torus(n=1000, c=2, a=1, noise=0.1)
    df = pd.DataFrame(torus, columns = ['x', 'y', 'z'])
   #df.to_csv('tori/torus_{}.tsv'.format(i), sep="\t", index=False)

# %%
fig = plt.figure(figsize = (7, 7))
ax = fig.add_subplot(projection='3d')
scat = ax.scatter(torus[:,2],torus[:,1], torus[:,0], s=10,edgecolors='black',alpha = 1)
plt.show()
